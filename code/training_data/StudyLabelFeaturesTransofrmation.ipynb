# %% [markdown]
# # Features Labels Shapes

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from pathlib import Path
import xgboost as xgb
import numpy as np
import matplotlib.pyplot as plt

# %%
data_dir = "../../preprocessed/" 
features_dir = data_dir + "regression_features/features_all/"
labels_dir = data_dir + "regression_labels/"

standardize_features = True

PCA_components = 64

USE_GEO = "GEO"

if USE_GEO == "GEO":
    features_columns = ["PCA"+str(i) for i in range(PCA_components)] + \
                        ["centroid_x", "centroid_y"]
else:
    features_columns = ["PCA"+str(i) for i in range(PCA_components)]
        

network_type = "vgg16_4096"

# %%
label_columns = ["hType_mix", "num_intersect", "bld_avg_age", "emp_rat_num",\
				"LUM5_single",	"RNR_nres", "mdist_smallparks", "nig_rat_daily",\
				"nig_rat_daily3", "mdist_nres_daily", "num_community_places", \
				"num_community_places_poi", "avg_block_area", "sphi", \
				"enterprises_empl_size", "pop_rat_num",  \
				"emp_rat_pop", "den_nres_daily",\
				"mdist_parks", "den_nres_non-daily", "mdist_railways",\
				"mdist_highways", "mdist_water", "activity_density"] # "bld_rat_area",

# %%
df = pd.read_csv(labels_dir + "roma" + "_imagelet_labels_clean.csv")

# %% [markdown]
# # Vitality, Activity Density

# %%
h = df[['label_activity_density']].hist(figsize=(10,12),layout=(4,3))
# Out:
# /anaconda3/envs/JJ/lib/python3.7/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /anaconda3/envs/JJ/lib/python3.7/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /anaconda3/envs/JJ/lib/python3.7/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /anaconda3/envs/JJ/lib/python3.7/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %% [markdown]
# # Land Use

# %%
land_use = [
"LUM5_single","RNR_nres","mdist_smallparks",
"hType_mix", "nig_rat_daily", "mdist_nres_daily",
"num_community_places", "num_community_places_poi"]
land_use_cols = ["label_"+l for l in land_use]

# %%
h = df[land_use_cols].hist(figsize=(10,12),layout=(4,3))

# %% [markdown]
# # Small Blocks

# %%
small_blocks = [
"avg_block_area","num_intersect", "sphi"]
small_blocks_cols = ["label_"+l for l in small_blocks]

# %%
h = df[small_blocks_cols].hist(figsize=(25,44),layout=(22,5))

# %% [markdown]
# # Age Buildings

# %%
age_buildings = [
"bld_avg_age","enterprises_empl_size"]
age_buildings_cols = ["label_"+l for l in age_buildings]

# %%
h = df[age_buildings_cols].hist(figsize=(25,44),layout=(22,5))

# %% [markdown]
# # Concentration

# %%
concentration = [
"pop_rat_num","emp_rat_num","emp_rat_pop"
    ,"den_nres_daily","den_nres_non-daily"]
concentration_cols = ["label_"+l for l in concentration]

# %%
h = df[concentration_cols].hist(figsize=(12,30),layout=(8,3))

# %% [markdown]
# # Vacuums

# %%
vacuums = ["mdist_parks", "mdist_railways",
"mdist_highways", "mdist_water"]
vacuums_cols = ["label_"+l for l in vacuums]

# %%
h = df[vacuums_cols].hist(figsize=(15,8),layout=(2,3))

# %% [markdown]
# # Updated Data

# %%
df = pd.read_csv(data_dir + "regression_features/features_separate_cities/Italy_6_cities_resnet_pca64_vgg16_4096_roma_labels_features.csv")

# %%
h = df[['label_activity_density']].hist(figsize=(5,5),layout=(1,1))

# %%
h = df[land_use_cols].hist(figsize=(10,12),layout=(4,3))

# %%
h = df[small_blocks_cols].hist(figsize=(25,44),layout=(22,5))

# %%
h = df[age_buildings_cols].hist(figsize=(25,44),layout=(22,5))

# %%
h = df[concentration_cols].hist(figsize=(12,30),layout=(8,3))

# %%
h = df[vacuums_cols].hist(figsize=(15,8),layout=(2,3))
